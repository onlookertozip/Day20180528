# %% [markdown]
# <a href="https://colab.research.google.com/github/onlookertozip/Day20180528/blob/master/Level1_3_%EC%9D%BC%EB%B3%80%EB%9F%89_%EC%A7%88%EC%A0%81_%EC%9E%90%EB%A3%8C_%EC%A0%95%EB%A6%AC%EC%99%80_%EC%9A%94%EC%95%BD_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [12, 8]

# %%
group_names = ['Group_A', 'Group_B', 'Group_C']

group_sizes = [95, 54, 25]

group_colors = ['yellowgreen', 'lightskyblue', 'lightcoral']

group_explodes = (0.1, 0, 0)

# %%
plt.pie(group_sizes, 

        explode=group_explodes, 

        labels=group_names, 

        colors=group_colors, 

        autopct='%1.2f%%', # second decimal place

        shadow=True, 

        startangle=90,

        textprops={'fontsize': 14}) # text font size

plt.axis('equal') #  equal length of X and Y axis

plt.title('Pie Chart of Market Share', fontsize=20)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

# %%
subgroup_names = ['A_1', 'A_2', 'A_3', 'A_4', 

                  'B_1', 'B_2', 'B_3', 

                  'C_1', 'C_2']

subgroup_sizes = [50, 30, 10, 5, 30, 20, 4, 20, 5]


a, b, c = [plt.cm.Reds, plt.cm.Greens, plt.cm.Blues]


width_num = 0.4

# %%
fig, ax = plt.subplots()

ax.axis('equal')

pie_outside, _ = ax.pie(group_sizes, 

                        radius=1.3, 

                        labels=group_names, 

                        labeldistance=0.8,

                        colors=[a(0.6), b(0.6), c(0.6)])

plt.setp(pie_outside, 

         width=width_num, 

         edgecolor='white')
# Out:
# [None, None, None, None, None, None]

# %%
pie_inside, plt_labels, junk = ax.pie(subgroup_sizes, 

           radius=(1.3 - width_num), 

           labels=subgroup_names, 

           labeldistance=0.75, 

           autopct='%1.1f%%', 

           colors=[a(0.5), a(0.4), a(0.3), a(0.2), 

                   b(0.5), b(0.4), b(0.3), 

                   c(0.5), c(0.4)])

plt.setp(pie_inside, 

         width=width_num, 

         edgecolor='white')

plt.title('Donut Plot with Subgroups', fontsize=20)

plt.show()
